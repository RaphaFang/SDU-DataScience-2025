# %%
import pandas as pd
df = pd.read_csv("/Users/fangsiyu/Desktop/sdu_courses/801_intro/w1/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'new_d'],
#       dtype='object')

# %%
df.shape
# Out:
# (8807, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df[df['release_year'] == 2020].sort_values(by='release_year', ascending=False)
# 最大就是2021，sum 592
# Out:
#      show_id     type                                            title  \
# 0         s1    Movie                             Dick Johnson Is Dead
# 2352   s2353  TV Show                                           Babies
# 2330   s2331    Movie  Eurovision Song Contest: The Story of Fire Saga
# 2331   s2332  TV Show                                        Home Game
# 2337   s2338  TV Show                                        Twogether
# ...      ...      ...                                              ...
# 1734   s1735    Movie                         Midnight at the Magnolia
# 1736   s1737    Movie                         Operation Christmas Drop
# 1737   s1738  TV Show                                       Paranormal
# 1740   s1741  TV Show                                   Love & Anarchy
# 8132   s8133  TV Show        Surviving R. Kelly Part II: The Reckoning
#
#              director                                               cast  \
# ...

# %%
df[df['rating'] == 'PG']
# Out:
#      show_id   type                              title  \
# 6         s7  Movie   My Little Pony: A New Generation
# 41       s42  Movie                               Jaws
# 42       s43  Movie                             Jaws 2
# 43       s44  Movie                             Jaws 3
# 45       s46  Movie             My Heroes Were Cowboys
# ...      ...    ...                                ...
# 8655   s8656  Movie               Unaccompanied Minors
# 8701   s8702  Movie  Water & Power: A California Heist
# 8776   s8777  Movie                         Yellowbird
# 8793   s8794  Movie               Yours, Mine and Ours
# 8805   s8806  Movie                               Zoom
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 41                 Steven Spielberg
# 42                   Jeannot Szwarc
# 43                        Joe Alves
# 45                      Tyler Greco
# ...                             ...
# 8655                      Paul Feig
# ...

# %%
df.value_counts('listed_in')
# Out:
# listed_in
# Dramas, International Movies                                  362
# Documentaries                                                 359
# Stand-Up Comedy                                               334
# Comedies, Dramas, International Movies                        274
# Dramas, Independent Movies, International Movies              252
#                                                              ...
# Cult Movies, Dramas, International Movies                       1
# Cult Movies, Dramas, Music & Musicals                           1
# Cult Movies, Dramas, Thrillers                                  1
# Cult Movies, Horror Movies, Thrillers                           1
# Crime TV Shows, TV Action & Adventure, TV Sci-Fi & Fantasy      1
# Name: count, Length: 514, dtype: int64

# %%
df['title'].str.contains('Love').sum()
# np.int64(188)
# Out:
# np.int64(188)

# %%
df.sort_values(by='release_year').head()
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %%
mask = df['duration'].str.contains(' min', na=False)
df['new_d'] = df.loc[mask, 'duration'].str.replace(" min", "", regex=False).astype(int)
df.sort_values(by="new_d", ascending=True)

mask = df['duration'].str.contains(' min', na=False)
df['chain_new_d'] = df[mask]['duration'].str.replace(" min", "", regex=False).astype(int)
df.sort_values(by="new_d", ascending=True)

# # 或者是寫成這樣 
# df['new_d'] = (
#     df['duration']
#       .where(df['duration'].str.contains(' min', na=False))  # 不符合的變成 NaN
#       .str.replace(" min", "", regex=False)
#       .astype(float)
#       .astype('Int64')
# )
# df.sort_values(by="new_d", ascending=True)
# Out:
#      show_id     type                                             title  \
# 3777   s3778    Movie                                            Silent
# 2713   s2714    Movie                                       Sol Levante
# 1484   s1485    Movie                                  Cops and Robbers
# 1557   s1558    Movie                                            Canvas
# 3535   s3536    Movie  American Factory: A Conversation with the Obamas
# ...      ...      ...                                               ...
# 8795   s8796  TV Show                                   Yu-Gi-Oh! Arc-V
# 8796   s8797  TV Show                                        Yunus Emre
# 8797   s8798  TV Show                                         Zak Storm
# 8800   s8801  TV Show                                Zindagi Gulzar Hai
# 8803   s8804  TV Show                                       Zombie Dumb
#
#                                director  \
# 3777  Limbert Fabian, Brandon Oldenburg
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# new_d           2679
# dtype: int64

# %%
new_df = df.dropna(subset=['director','cast','country'])
new_df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast              0
# country           0
# date_added        0
# release_year      0
# rating            1
# duration          3
# listed_in         0
# description       0
# new_d           150
# dtype: int64
